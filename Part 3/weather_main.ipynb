# %%
import os

os.environ["OPENAI_API_KEY"] = "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"  # Prevents CrewAI from defaulting to OpenAI

# %%
from crewai import Agent, Crew, Task
from weather_tool import get_weather_data

# Define the Weather Agent with backstory
weather_agent = Agent(
    role="Weather Assistant",
    goal="Provide weather forecasts in London for next 4 days.",
    tools=[get_weather_data],
    backstory="You are a helpful assistant that provides accurate weather forecasts for cities around the world.",
    verbose=True
)

# Define a Task for the agent
weather_task = Task(
    agent=weather_agent,
    description="Retrieve the weather forecast for next 4 days.",
    expected_output="Select the day has good weather for going out",
)

# Create a Crew and assign the task
crew = Crew(
    agents=[weather_agent],
    tasks=[weather_task],
    verbose=True  # Enable detailed logs for debugging
)

# Run the task
result = crew.kickoff()

# Print the result
print("\n=== FINAL RESULTS ===\n", result)
# Out:
#
# [2025-05-02 03:58:25][🚀 CREW 'CREW' STARTED, 2DBEB682-E553-428E-AAB5-001133C543B9]: 2025-05-02 03:58:25.084424
#
# [2025-05-02 03:58:25][📋 TASK STARTED: RETRIEVE THE WEATHER FORECAST FOR NEXT 4 DAYS.]: 2025-05-02 03:58:25.087808
#
# [2025-05-02 03:58:25][🤖 AGENT 'WEATHER ASSISTANT' STARTED TASK]: 2025-05-02 03:58:25.088489
# # Agent: Weather Assistant
# ## Task: Retrieve the weather forecast for next 4 days.
#
# [2025-05-02 03:58:25][🤖 LLM CALL STARTED]: 2025-05-02 03:58:25.088582
#
# [2025-05-02 03:58:26][✅ LLM CALL COMPLETED]: 2025-05-02 03:58:26.326791
#
# [2025-05-02 03:58:26][🤖 TOOL USAGE STARTED: 'GET WEATHER FORECAST']: 2025-05-02 03:58:26.327202
#
# [2025-05-02 03:58:26][✅ TOOL USAGE FINISHED: 'GET WEATHER FORECAST']: 2025-05-02 03:58:26.477311
#
#
# # Agent: Weather Assistant
# ## Thought: I need to fetch the weather forecast for London for the next 4 days to determine which day has good weather for going out.
# ## Using tool: Get Weather Forecast
# ## Tool Input:
# ...
