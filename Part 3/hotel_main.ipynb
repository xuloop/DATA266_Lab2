# %%
import os

os.environ["OPENAI_API_KEY"] = "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"  # Prevents CrewAI from defaulting to OpenAI

# %%
from crewai import Agent, Crew, Task
from hotel_tool import get_hotel_data_combined

# Define the agent
hotel_agent = Agent(
    role="Hotel Travel Assistant",
    goal="Help users find and compare hotel offers with ratings in a given city and date range",
    backstory=(
        "You are an experienced travel assistant specializing in hotel booking and comparison. "
        "You can search hotels, check availability, and summarize pricing, location, and guest ratings."
    ),
    tools=[get_hotel_data_combined],
    verbose=True
)

# Define the task
hotel_task = Task(
    description=(
        "Search for hotels in the city code 'LON' from 2025-05-05 to 2025-05-10 for 2 adults. "
        "Display name, location, price, room type, and rating."
    ),
    expected_output="List 3 good hotels and recommend the best one based on ratings, prices, and room descriptions.",
    agent=hotel_agent
)

# Assemble and run the crew
crew = Crew(
    agents=[hotel_agent],
    tasks=[hotel_task],
    verbose=True
)

results = crew.kickoff()
print("\n=== FINAL RESULTS ===\n", results)
# Out:
#
# [2025-05-02 03:51:23][🚀 CREW 'CREW' STARTED, AF0405F0-A6AF-491A-A342-DC380ABB46D8]: 2025-05-02 03:51:23.868430
#
# [2025-05-02 03:51:23][📋 TASK STARTED: SEARCH FOR HOTELS IN THE CITY CODE 'LON' FROM 2025-05-05 TO 2025-05-10 FOR 2 ADULTS. DISPLAY NAME, LOCATION, PRICE, ROOM TYPE, AND RATING.]: 2025-05-02 03:51:23.875391
#
# [2025-05-02 03:51:23][🤖 AGENT 'HOTEL TRAVEL ASSISTANT' STARTED TASK]: 2025-05-02 03:51:23.876655
# # Agent: Hotel Travel Assistant
# ## Task: Search for hotels in the city code 'LON' from 2025-05-05 to 2025-05-10 for 2 adults. Display name, location, price, room type, and rating.
#
# [2025-05-02 03:51:23][🤖 LLM CALL STARTED]: 2025-05-02 03:51:23.876857
#
# [2025-05-02 03:51:25][✅ LLM CALL COMPLETED]: 2025-05-02 03:51:25.376800
#
# [2025-05-02 03:51:25][🤖 TOOL USAGE STARTED: 'SEARCH HOTELS']: 2025-05-02 03:51:25.377647
#
# [2025-05-02 03:51:35][✅ TOOL USAGE FINISHED: 'SEARCH HOTELS']: 2025-05-02 03:51:35.466165
#
#
# # Agent: Hotel Travel Assistant
# ...
