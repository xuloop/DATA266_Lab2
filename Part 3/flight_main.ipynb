# %%
import os

os.environ["OPENAI_API_KEY"] = "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"  # Prevents CrewAI from defaulting to OpenAI

# %%
from crewai import Agent, Crew, Task
#from crew_agents import flight_agent  
from flight_tool import search_flights  

# Register the tool with the agent
#flight_agent.tools = [search_flights]

# Define the agent
flight_agent = Agent(
    role="Flight Search Agent",
    goal="Find the best flight based on user needs",
    backstory="You are a skilled travel assistant specializing in flights.",
    tools=[search_flights],
    verbose=True
)

# Create a flight search task
flight_task = Task(
    description="Find the 2 nonstop flights from NYC to LON for 2 people, departing on 2025-05-05 and returning on 2025-05-10.",
    expected_output="List 3 good flight options and recommend the best one.",
    agent=flight_agent
)

# Create a Crew and assign the task
crew = Crew(
    agents=[flight_agent],
    tasks=[flight_task],
    verbose=True  # Enable detailed logs for debugging
)

# Run the crew
if __name__ == "__main__":
    results = crew.kickoff()
    print("\n=== FINAL RESULTS ===\n", results)
# Out:
#
# [2025-05-02 04:11:22][🚀 CREW 'CREW' STARTED, B2D89C29-0F7F-426A-9A37-E92EE7B4A401]: 2025-05-02 04:11:22.294855
#
# [2025-05-02 04:11:22][📋 TASK STARTED: FIND THE 2 NONSTOP FLIGHTS FROM NYC TO LON FOR 2 PEOPLE, DEPARTING ON 2025-05-05 AND RETURNING ON 2025-05-10.]: 2025-05-02 04:11:22.298380
#
# [2025-05-02 04:11:22][🤖 AGENT 'FLIGHT SEARCH AGENT' STARTED TASK]: 2025-05-02 04:11:22.298932
# # Agent: Flight Search Agent
# ## Task: Find the 2 nonstop flights from NYC to LON for 2 people, departing on 2025-05-05 and returning on 2025-05-10.
#
# [2025-05-02 04:11:22][🤖 LLM CALL STARTED]: 2025-05-02 04:11:22.299020
#
# [2025-05-02 04:11:25][✅ LLM CALL COMPLETED]: 2025-05-02 04:11:25.886904
#
# [2025-05-02 04:11:25][🤖 TOOL USAGE STARTED: 'SEARCH FLIGHTS']: 2025-05-02 04:11:25.887316
# Tool called with: origin=NYC, destination=LON, departure_date=2025-05-05, return_date=2025-05-10, adults=2, max_results=3, non_stop=True
#
# ...
